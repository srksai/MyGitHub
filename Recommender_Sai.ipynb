# %%
import pandas as pd
import numpy as np

# %%
M = pd.read_csv("Movie Reviews.csv", index_col='Name')

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %% [markdown]
# ###Question 1:  What movie is most Similar to 'The fault in our stars' (60 pts)

# %%
M
# Out:
#                      American Sniper  The Hunger Games: Mockingjay - Part 1  \
# Name
# Mike                             NaN                                    NaN
# HJ SONG                          NaN                                      2
# Ryan Hansen                      NaN                                      3
# Olumuyiwa Durojaiye              NaN                                    NaN
# Charlie                          NaN                                      2
# Sina Tuy                         NaN                                      3
# Pavithra Shetty                  NaN                                      3
# Sara Collins                     NaN                                      5
# Jonathan Doll                    NaN                                      4
# saikiran reddy                     3                                      4
# Aishwarya reddy                  NaN                                      3
# ...

# %%
recs = get_recs('The Fault in Our Stars', M, 10)

# %%
recs[:10]
# Out:
# [('Transformers', 0.47140855664850745),
#  ('The Hunger Games: Mockingjay - Part 1', 0.35345113364519332),
#  ('How to Train your Dragon 2', 0.32529176115432162),
#  ('Godzilla', 0.30435653111862088),
#  ('Malificent', 0.25203347226782336),
#  ('300: Rise of an Empire', 0.16718738300211244),
#  ('Guardians of the Galaxy', 0.14306584587982532),
#  ('Gone Girl', 0.083747586093265186),
#  ('The Lego Movie', 0.061313933948496616),
#  ('Interstellar', -0.081751911931328733)]

# %% [markdown]
# ###Question 2:  Which movie(s) would you most like to see, based on your classmates experience? (40 pts)

# %%
#HINTS...

#the movies I've seen
my_ratings = M.ix['Mike'].dropna()
#the movie I've rated the highest
my_ratings.sort(ascending=False)
#the name of the movie I've rated the highest
fav_movie = my_ratings.index[0]
print(my_ratings)
# Out:
# Guardians of the Galaxy    5
# The Hobbit                 4
# Divergent                  3
# Malificent                 3
# 300: Rise of an Empire     2
# Name: Mike, dtype: float64

# %%
#the movies I've seen
sai_ratings = M.ix['Sai Yallapragada'].dropna()
#the movie I've rated the highest
sai_ratings.sort(ascending=False)
#the name of the movie I've rated the highest
sai_fav_movie = sai_ratings.index[0]
print(sai_ratings)
sai_fav_movie
# Out:
# Interstellar                             5
# American Sniper                          5
# 300: Rise of an Empire                   4
# Transformers                             3
# The Lego Movie                           3
# Divergent                                2
# Guardians of the Galaxy                  2
# The Hunger Games: Mockingjay - Part 1    2
# Godzilla                                 1
# Name: Sai Yallapragada, dtype: float64
# 'Interstellar'

# %% [markdown]
# ###Alright, we all know what my fav movie is...lets find out what my classmates have to say

# %%
def get_classMates(M, excluding_name, compar_fav_movie):
    classMates_movie_ratings = []
    N = M.drop(excluding_name)
    classMates_movie_ratings = get_recs(compar_fav_movie, N, 5)
    return classMates_movie_ratings

# %%
get_classMates(M, 'Sai Yallapragada', sai_fav_movie)
# Out:
# [('The Lego Movie', 0.51136363636363635),
#  ('The Hobbit', 0.31558589931628583),
#  ('How to Train your Dragon 2', 0.25033322825131543),
#  ('Malificent', 0.24214407138347413),
#  ('Unbroken', 0.13055824196677326)]

# %% [markdown]
# ### So, I took out my ratings and passed the value of my fav movie and based on my taste and they recommended "The Lego Movie"

# %% [markdown]
# ###Question 3: Bonus Question...  For all the movies you haven't seen, can you predict how you'd rate them using your the class reviews? (10 pts)
